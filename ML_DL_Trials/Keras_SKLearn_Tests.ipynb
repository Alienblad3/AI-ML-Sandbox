# %% [markdown]
# 23MAI1012 - Sanjay Bharath DL Lab 2

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
# Out:
# 2024-02-06 21:46:31.434408: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-06 21:46:31.434442: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-06 21:46:31.435150: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-06 21:46:31.440598: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
x, y = make_moons(n_samples=500, noise=0.1, random_state=42)

# %%
plt.scatter(x[:, 0], x[:, 1], c=y, marker='o', edgecolors='k')
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
#Model 1
#Single Layer, SDG Optimizer, 100 Epochs
tf.random.set_seed(42)
model1 = tf.keras.Sequential([
  tf.keras.layers.Dense(10),
])
model1.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.SGD(),
                metrics=['accuracy'])
model1.fit(x, y, epochs=100)
# Out:
# Epoch 1/100
# 2024-02-06 21:47:03.288534: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-06 21:47:03.319937: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...

# %%
#Model 2
#Multiple Layers, SDG Optimizer, 100 Epochs
tf.random.set_seed(42)
model1 = tf.keras.Sequential([
  tf.keras.layers.Dense(100),
  tf.keras.layers.Dense(10),
  tf.keras.layers.Dense(1),
])
model1.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.SGD(),
                metrics=['accuracy'])
model1.fit(x, y, epochs=100)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 1s 3ms/step - loss: 0.6256 - accuracy: 0.6320
# Epoch 2/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4220 - accuracy: 0.7080
# Epoch 3/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3489 - accuracy: 0.7840
# Epoch 4/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3025 - accuracy: 0.8200
# Epoch 5/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2797 - accuracy: 0.8280
# Epoch 6/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2631 - accuracy: 0.8360
# Epoch 7/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2531 - accuracy: 0.8440
# Epoch 8/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2455 - accuracy: 0.8540
# Epoch 9/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2428 - accuracy: 0.8580
# Epoch 10/100
# ...

# %%
#Model 3
#Multiple Layers, Adam Optimizer, 150 Epochs
tf.random.set_seed(42)
model1 = tf.keras.Sequential([
  tf.keras.layers.Dense(100),
  tf.keras.layers.Dense(10),
  tf.keras.layers.Dense(1),
])
model1.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])
model1.fit(x, y, epochs=150)
# Out:
# Epoch 1/150
# 16/16 [==============================] - 1s 3ms/step - loss: 0.6447 - accuracy: 0.6620
# Epoch 2/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4185 - accuracy: 0.7920
# Epoch 3/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2926 - accuracy: 0.8200
# Epoch 4/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2641 - accuracy: 0.8380
# Epoch 5/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2433 - accuracy: 0.8540
# Epoch 6/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2353 - accuracy: 0.8660
# Epoch 7/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2316 - accuracy: 0.8720
# Epoch 8/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2324 - accuracy: 0.8680
# Epoch 9/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2323 - accuracy: 0.8760
# Epoch 10/150
# ...

# %% [markdown]
# Model 3 perform the best.
